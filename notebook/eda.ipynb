# %%
import os
print(os.getcwd())
# Out:
# c:\Users\manoj\Desktop\animal_diseases\notebook

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/full_animal_disease_dataset.csv")

# %%
print(df.columns)
# Out:
# Index(['Animal', 'Age', 'Gender', 'Breed', 'WBC', 'RBC', 'Hemoglobin',
#        'Platelets', 'Glucose', 'ALT', 'AST', 'Urea', 'Creatinine',
#        'Symptom_Fever', 'Symptom_Lethargy', 'Symptom_Vomiting',
#        'Symptom_Diarrhea', 'Symptom_WeightLoss', 'Symptom_SkinLesion',
#        'Disease_PPR', 'Disease_Anthrax', 'Disease_FootRot',
#        'Disease_Enterotoxemia', 'Disease_Parasites',
#        'Disease_CaprineArthritisEncephalitis', 'Disease_CaseousLymphadenitis',
#        'Disease_Anemia', 'Disease_Leukemia', 'Disease_ViralInfection',
#        'Disease_BloodParasites', 'Disease_BacterialInfection',
#        'Disease_AvianLeukosis', 'Disease_DuckViralDiseases', 'Disease_Colic',
#        'Disease_Strangles', 'Disease_EquineInfluenza', 'Disease_Laminitis',
#        'Disease_Rabies', 'Disease_EquineAnemia',
#        'Disease_EquineInfectiousAnemia', 'Disease_Bluetongue',
#        'Disease_Scrapie', 'Disease_OvineJohnesDisease', 'Disease_SheepPox',
# ...

# %%
df.head()
# Out:
#     Animal  Age  Gender   Breed       WBC   RBC  Hemoglobin  Platelets  \
# 0     Goat    9    Male  Breed1  11309.65  4.07       14.85  159922.26
# 1    Tiger   20  Female  Breed2  12632.06  5.43       17.76  275429.67
# 2  Tilapia    7  Female  Breed1  14801.22  7.52       17.86  277542.42
# 3    Goose    4    Male  Breed1   8121.27  4.32       14.22  169530.08
# 4    Horse   13  Female  Breed2   5868.70  4.79       16.76  246184.67
#
#    Glucose    ALT  ...  Disease_Erysipelas  Disease_Trypanosomiasis  \
# 0    80.17  48.43  ...                 NaN                      NaN
# 1    64.50  18.31  ...                 NaN                      NaN
# 2    89.51  47.46  ...                 NaN                      NaN
# 3   102.09  44.72  ...                 NaN                      NaN
# 4    82.72  40.81  ...                 NaN                      NaN
#
#    Disease_HemorrhagicSepticemia  Disease_WetTail  \
# 0                            NaN              NaN
# ...

# %%
print(df.columns)
# Out:
# Index(['Animal', 'Age', 'Gender', 'Breed', 'WBC', 'RBC', 'Hemoglobin',
#        'Platelets', 'Glucose', 'ALT', 'AST', 'Urea', 'Creatinine',
#        'Symptom_Fever', 'Symptom_Lethargy', 'Symptom_Vomiting',
#        'Symptom_Diarrhea', 'Symptom_WeightLoss', 'Symptom_SkinLesion',
#        'Disease_PPR', 'Disease_Anthrax', 'Disease_FootRot',
#        'Disease_Enterotoxemia', 'Disease_Parasites',
#        'Disease_CaprineArthritisEncephalitis', 'Disease_CaseousLymphadenitis',
#        'Disease_Anemia', 'Disease_Leukemia', 'Disease_ViralInfection',
#        'Disease_BloodParasites', 'Disease_BacterialInfection',
#        'Disease_AvianLeukosis', 'Disease_DuckViralDiseases', 'Disease_Colic',
#        'Disease_Strangles', 'Disease_EquineInfluenza', 'Disease_Laminitis',
#        'Disease_Rabies', 'Disease_EquineAnemia',
#        'Disease_EquineInfectiousAnemia', 'Disease_Bluetongue',
#        'Disease_Scrapie', 'Disease_OvineJohnesDisease', 'Disease_SheepPox',
# ...
